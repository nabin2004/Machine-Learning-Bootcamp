# %% [markdown]
# # Episode 0 — ML from the bottom up — From scratch
#
# **Act 3 — From scratch** (NumPy for classical ML; raw autograd / tensors for DL)

# %% [markdown]
# ## Goal
#
# Replicate the **library run** notebook on the **same** data with the **same** hyperparameters.
# End with a side-by-side parity check in this notebook (no separate test suite required).

# %%
from common.seeds import set_all

set_all(42)

# from scratch.core import fit_from_scratch, predict_from_scratch

print("From-scratch path — implement core.py then import here.")

# %% [markdown]
# ## Parity cell (fill in)
#
# Compare predictions / losses / weights against Act 2.

# %%
# TODO: print_side_by_side("library", lib_pred, "scratch", scratch_pred)
pass
