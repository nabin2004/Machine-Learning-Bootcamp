# %% [markdown]
# # Episode 0 — ML from the bottom up
#
# **Act 1 — Intuition** (whiteboard / geometry / loss — minimal code)

# %% [markdown]
# ## What is this algorithm doing?
#
# - Geometry of the data
# - Shape of the objective / constraints
# - "What it cares about" in plain language

# %% [markdown]
# ### Placeholder prompts
#
# - Draw the model as a graph of computations.
# - Where do gradients flow / where do trees split?

# %%
from common.seeds import set_all

set_all(42)
print("Intuition deck — RISE slideshow metadata enabled.")
