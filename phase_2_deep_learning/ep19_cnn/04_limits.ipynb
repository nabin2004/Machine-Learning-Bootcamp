# %% [markdown]
# # Convolutional neural networks — Limits
#
# **Act 4 — Limits** (where it breaks in the real world)

# %% [markdown]
# ## Checklist (delete what does not apply)
#
# - **Scaling / preprocessing** sensitivity
# - **Class imbalance** or rare events
# - **Numerical issues** (overflow, log(0), vanishing / exploding gradients)
# - **Distribution shift** between train and deploy
# - **Inductive bias limits** (linearity, independence assumptions, etc.)

# %%
from common.seeds import set_all

set_all(42)
print("Limits notebook — add experiments that *break* the method.")

# %% [markdown]
# ## Experiment stubs
#
# Add small code cells with plots / metrics showing failure modes.

# %%
# TODO: stress tests
pass
