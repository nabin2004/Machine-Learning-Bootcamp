# %% [markdown]
# # Backpropagation (manual) — Library run
#
# **Act 2 — Library** (sklearn / PyTorch / HF: minimal, clean, correct API)

# %% [markdown]
# ## Setup
#
# - Import the library you teach in this episode.
# - Fix seeds via ``common.seeds.set_all`` before touching randomness.

# %%
from common.seeds import set_all

set_all(42)

# TODO: import library (e.g. sklearn, torch, transformers)
print("Library path — add minimal fit/predict or training loop.")

# %% [markdown]
# ## Fit / train
#
# Keep this notebook short: one clear path from data → metric.

# %%
# TODO: load toy or real data; fit; report metric
pass
